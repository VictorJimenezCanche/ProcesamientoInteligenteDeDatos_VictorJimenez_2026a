# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Datos
data={'ingreso':[1452,1361,1426,1470,1456,1430,1354,1442,1394,1459,
           1399,1458,1537,1425,1445,1439,1348,1450,1431,1446,
           1485,1405,1461,1490,1426],
'habitaciones':[23,47,21,39,37,29,23,44,45,16,
                30,42,54,27,34,15,19,38,44,47,
                43,38,51,61,39]}

# %%
#Crear dataframe
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["habitaciones"], df["ingreso"], color='blue', alpha=0.6)
plt.xlabel("Habitaciones Ocupadas")
plt.ylabel("Ingreso Restaurante ($)")
plt.title("Gráfica de Correlación")
plt.show()

# %% [markdown]
# **Interpretación**
# Los puntos muestran una ligera inclinación ascendente.
# Esto indica que cuando aumentan las habitaciones ocupadas, el ingreso del restaurante tiende a aumentar.
